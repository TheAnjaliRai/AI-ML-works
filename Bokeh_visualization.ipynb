# %% [markdown]
# <a href="https://colab.research.google.com/github/TheAnjaliRai/AI-ML-works/blob/main/Bokeh_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure , output_file , show
from bokeh.sampledata.iris import flowers

output_file('test.html')
p = figure(title = "test flower")
p.xaxis.axis_label = "petal length"
p.yaxis.axis_label = "petal width"
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="e499f7e0-9f8c-4012-b117-040214970f2f" data-root-id="p1001" style="display: contents;"></div>

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from bokeh.plotting import figure , output_file , show
from bokeh.sampledata.iris import flowers

output_file('test.html')
p = figure(title = "test flower")
p.xaxis.axis_label = "petal length"
p.yaxis.axis_label = "petal width"
p.line(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="ca8e004e-573d-4345-9f97-51f3585c62dc" data-root-id="p1048" style="display: contents;"></div>

# %%
from bokeh.plotting import figure , output_file , show
from bokeh.sampledata.iris import flowers
x = [2,3,4,6,7,8,9]
y = [4,6,7,8,5,3,3]
output_file('line.html')
p = figure(title = "line plot")
p.xaxis.axis_label = "x axis"
p.yaxis.axis_label = "y axis"
p.line(x,y)
show(p)
# Out:
#   File "<ipython-input-7-6abbf22183ba>", line 7
#     p.xaxis.axis_label = "x axis",
#     ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
x = [2,3,4,6,7,8,9]
y = [4,6,7,8,5,3,3]
output_file('scatter.html')
p = figure(title = "scatter plot")
p.xaxis.axis_label = "x axis"
p.yaxis.axis_label = "y axis"
p.scatter(x,y , fill_color = 'red' , legend_label = 'red points' , size = 20)
show(p)
# Out:
#   <div id="da84e8fd-34da-42b8-83d4-57c59c03f980" data-root-id="p1269" style="display: contents;"></div>

# %%
import bokeh.io
from bokeh.plotting import figure,output_file , show

# %%
from bokeh.sampledata.iris import flowers

# %%
bokeh.io.output_file('test.html')

p = figure(title="Test Flower")
p.xaxis.axis_label = "Petal Length"
p.yaxis.axis_label = "Petal Width"
p.circle(flowers['petal_length'], flowers['petal_width'])

show(p)
# Out:
#   <div id="c9d879eb-2456-40ed-a93a-a8aa29f8f4fa" data-root-id="p1001" style="display: contents;"></div>

# %%
from bokeh.plotting import figure , output_file , show
from bokeh.sampledata.iris import flowers

output_file('test.html')
p = figure(title = "test flower",x_axis_label = "petal length" , y_axis_label = "petal width")
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="c9378391-2715-416e-880b-524a0866971d" data-root-id="p1048" style="display: contents;"></div>
